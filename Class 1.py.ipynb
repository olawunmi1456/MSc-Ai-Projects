# %% [markdown]
# # Jupyter Notebook

# %% [markdown]
# Class outline:
#
# * [What is the Jupyter Notebook?](files/What%20is%20the%20Jupyter%20Notebook.ipynb)
# * [Notebook Basics](files/Notebook%20Basics.ipynb)
# * [Markdown Cells](files/Working%20With%20Markdown%20Cells.ipynb)
# * [Running Code](files/Running%20Code.ipynb)
# * [Custom Keyboard Shortcuts](files/Custom%20Keyboard%20Shortcuts.ipynb)

# %%
# Initiate n1 and n2.
n1 =  0
n2 = 1
# print n1
print(n1)

# while loop when n2 is less than 22
while n2 < 22:
    # print n2 when less than 22
    print (n2)
    n1, n2 = n2, n1 + n2
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21
